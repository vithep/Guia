# %% [markdown]
# # 3.5 Guia - Floresta de Decisão

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings

# %%
Base_dados=pd.read_csv('Stars.csv')

# %%
Base_dados.head()
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0

# %%
# Verificando as colunas
for c in Base_dados.columns:
    print(c)
# Out:
# Temperature
# L
# R
# A_M
# Color
# Spectral_Class
# Type

# %%
# Verificando a dimensão dos dados
Base_dados.shape
# Out:
# (240, 7)

# %%
# Verificando o Formato dos Campos
Base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature     240 non-null    int64
#  1   L               240 non-null    float64
#  2   R               240 non-null    float64
#  3   A_M             240 non-null    float64
#  4   Color           240 non-null    object
#  5   Spectral_Class  240 non-null    object
#  6   Type            240 non-null    int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %%
Base_dados.describe()
# Out:
#         Temperature              L            R         A_M        Type
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    2.500000
# std     9552.425037  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000

# %%
# configurar a visualização
#%matplotlib inline
# %config InlineBackend.figure_format = 'svg'
#configurando parâmetros das fontes
plt.rcParams['font.family'] = 'sans-serif'

# %%
# Verificando se temos valores nulos
fig,ax = plt.subplots(figsize=(10,6))
sns.heatmap(Base_dados.isnull());

# %%
# Verificando correlação
fig,ax = plt.subplots(figsize=(10,6))
mask = np.triu(np.ones_like(Base_dados.corr(), dtype=np.bool))
sns.heatmap(Base_dados.corr(), linewidths=.1,cmap='viridis',annot=True,mask=mask);

# %%
# Explorar todos os dados
sns.pairplot(Base_dados);

# %%
# Plotagem da Temperatura
fig,ax = plt.subplots(figsize=(10,5))
ax.hist(Base_dados['Temperature'], color = "skyblue")
sns.set(style='darkgrid')
plt.xlabel('Temperatura')
plt.ylabel('Quantidade')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=0,
        y=130,
        s='Histograma de Temperatura',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Luminosidade
fig,ax = plt.subplots(figsize=(10,5))
ax.hist(Base_dados['L'], color='r')
sns.set(style='whitegrid')
plt.xlabel('Luminosidade')
plt.ylabel('Quantidade')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=0,
        y=166,
        s='Histograma de Luminosidade',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Tamanho das Estrelas
fig,ax = plt.subplots(figsize=(10,5))
ax.hist(Base_dados['R'], color='g')
sns.set(style='whitegrid')
plt.xlabel('Tamanho')
plt.ylabel('Quantidade')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=0,
        y=215,
        s='Histograma de Tamanho das Estrelas',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Magnitude das Estrelas
fig,ax = plt.subplots(figsize=(10,5))
ax.hist(Base_dados['A_M'], color='y')
sns.set(style='whitegrid')
plt.xlabel('Magnitude')
plt.ylabel('Quantidade')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=-15,
        y=65,
        s='Histograma de Magnitude das Estrelas',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Tamanho das Estrelas
fig,ax = plt.subplots(figsize=(10,5))
ax.hist(Base_dados['Spectral_Class'], color='orange')
sns.set(style='whitegrid')
plt.xlabel('Tamanho')
plt.ylabel('Quantidade')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=0,
        y=120,
        s='Histograma de Tamanho das Estrelas',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Cores das Estrelas
fig,ax = plt.subplots(figsize=(10,5))
ax.hist(Base_dados['Color'], color='grey')
sns.set(style='whitegrid')
plt.xlabel('Cores')
plt.ylabel('Quantidade')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=0,
        y=140,
        s='Histograma de Cores das Estrelas',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Cores das Estrelas
fig,ax = plt.subplots(figsize=(10,5))
sns.boxplot(x='Type',y='A_M',data=Base_dados)
sns.set(style='darkgrid')

# Remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Adicionando um título
plt.text(x=-1,
        y=25,
        s='Boxplot de Magnitude das Estrelas',
        fontsize=16,
        color='grey',
        weight='bold');

# %%
# Preparando o Modelo

x = Base_dados.iloc[:,0:4].values
y = Base_dados.iloc[:,6:7].values

from sklearn.preprocessing import StandardScaler

Escala_x = StandardScaler()
x = Escala_x.fit_transform(x);

# %%
# Criando o Modelo

from sklearn.model_selection import train_test_split

x_treinamento, x_teste, y_treinamento, y_teste = train_test_split(x,y,test_size = 0.2)

from sklearn.ensemble import RandomForestClassifier

Algoritmo_Floresta_Decisao = RandomForestClassifier(n_estimators=500)
Algoritmo_Floresta_Decisao.fit(x_treinamento,y_treinamento);
# Out:
# <ipython-input-64-c20381e9f7c3>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Algoritmo_Floresta_Decisao.fit(x_treinamento,y_treinamento);

# %%
# Avaliando o modelo

y_predicoes = Algoritmo_Floresta_Decisao.predict(x_teste)

from sklearn.metrics import accuracy_score
Acuracio_Score = accuracy_score (y_teste,y_predicoes)
Acuracio_Score
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
Matriz_Confusao = confusion_matrix(y_teste,y_predicoes)

sns.heatmap(Matriz_Confusao,annot=True);

# %%
from sklearn.metrics import classification_report
Previsao = classification_report(y_teste,y_predicoes)
print(Previsao)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         7
#            3       1.00      1.00      1.00         6
#            4       1.00      1.00      1.00         6
#            5       1.00      1.00      1.00         8
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48
